# %% [markdown]
# Deep Learning
# =============
#
# Word2Vec and skip-gram models
# ------------
#
# Task - to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
print(filename)
# Out:
# Found and verified text8.zip
# text8.zip

# %% [markdown]
# Read the data into a string.

# %%
f=zipfile.ZipFile(filename)

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
di=dict()
di={'hell':[1,2,3],'hai':[1,2]}
len(di)
# Out:
# 2

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', [reverse_dictionary[di] for di in data[:10]])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against']

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
for i in [0,1,2,3]:
    print(random.randint(0,1))
# Out:
# 1
# 1
# 0
# 0

# %% [markdown]
# Interesting thing is the while loop-----> helps in initializing that position in the window(buffer), tat have not been seen/taken into accout so far

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1) # continue till an unseen 
        #target is found
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['anarchism', 'as', 'a', 'originated', 'as', 'term', 'a', 'of']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['anarchism', 'term', 'a', 'originated', 'term', 'as', 'originated', 'of']

# %%
np.array(batch[1]).shape
# Out:
# ()

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed,
                               train_labels, num_sampled, vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.767999
# Nearest to however: thoroughbred, ima, degeneracy, unsophisticated, bonhomme, daimlerchrysler, wingspan, andre,
# Nearest to b: nintendo, nellie, monotheist, albarn, jive, guildhall, charlottenburg, churning,
# Nearest to the: dacko, cke, towels, automator, adware, salesman, municipal, operand,
# Nearest to zero: effecting, ecumenical, affectionately, bowmen, ayman, crete, lawrencium, jabberwock,
# Nearest to there: korzybski, anatolian, trunk, jennie, volcanoes, saumur, der, sandpaper,
# Nearest to no: steppenwolf, aleksander, specialist, lindy, topology, horseshoes, kissed, recede,
# Nearest to which: talmud, subways, harmonious, wattle, melos, lindsay, disavow, marshall,
# Nearest to united: maidens, crevasses, halifax, aleksandar, crashes, food, orthopedic, reunion,
# Nearest to three: pollution, mawr, multilinear, parsons, formality, properly, warner, zimmerman,
# Nearest to were: rin, eleventh, sand, biochemistry, micrograms, medina, chiuchow, venerate,
# Nearest to two: urls, favorites, overdrive, calming, marty, katzenjammer, unknown, unloaded,
# Nearest to used: segmentation, fencer, checks, munster, illustrations, reaffirmed, provider, favre,
# Nearest to four: flatulence, prima, diffraction, wimp, semigroup, stanbul, draining, hegelian,
# Nearest to also: boardgamegeek, besides, xenakis, magus, says, binet, recycled, stagnation,
# Nearest to are: mackintosh, infty, maximise, bingen, tramlink, artistically, dominique, recurring,
# Nearest to would: rabbani, turboprop, sandinista, retreating, ananda, quran, keynesian, ashton,
# Average loss at step 2000: 4.362713
# Average loss at step 4000: 3.859788
# Average loss at step 6000: 3.788690
# Average loss at step 8000: 3.686825
# Average loss at step 10000: 3.617552
# Nearest to however: but, thoroughbred, braided, slocum, wojciech, transgressions, ima, kreutzmann,
# Nearest to b: d, gimmick, albarn, monotheist, savannas, tabulated, mississippian, claudine,
# Nearest to the: a, this, its, his, an, their, institutes, proclamation,
# Nearest to zero: nine, eight, six, five, seven, four, three, two,
# Nearest to there: it, he, not, they, quack, mobs, monosodium, saumur,
# Nearest to no: steppenwolf, aleksander, amid, lindy, canine, horseshoes, chromosomes, frequently,
# Nearest to which: that, this, who, loudspeakers, it, actually, cricketing, marshall,
# Nearest to united: halifax, crashes, aleksandar, crucifixion, princess, backed, shards, lottery,
# Nearest to three: six, four, eight, seven, five, two, nine, zero,
# Nearest to were: are, was, is, ancients, been, outmoded, by, have,
# Nearest to two: three, five, six, four, eight, nine, zero, seven,
# Nearest to used: known, provider, colorful, cried, factorials, prairie, faltered, munster,
# Nearest to four: three, eight, six, five, seven, two, zero, nine,
# Nearest to also: whiz, childless, often, he, kohanim, it, been, now,
# Nearest to are: were, is, have, euphoria, was, artistically, be, ayatollah,
# Nearest to would: can, could, to, will, may, must, might, contacts,
# Average loss at step 12000: 3.608092
# Average loss at step 14000: 3.567077
# Average loss at step 16000: 3.405382
# Average loss at step 18000: 3.454495
# Average loss at step 20000: 3.537314
# Nearest to however: but, vr, transgressions, slocum, thoroughbred, wingspan, particular, although,
# Nearest to b: d, gimmick, albarn, csv, mississippian, savannas, nylon, vane,
# Nearest to the: its, their, his, this, a, any, some, these,
# Nearest to zero: five, six, seven, nine, eight, three, four, two,
# Nearest to there: it, they, he, which, no, not, often, still,
# Nearest to no: steppenwolf, lindy, there, amid, aleksander, canine, a, frequently,
# Nearest to which: who, this, that, also, it, and, located, always,
# Nearest to united: halifax, army, crashes, lottery, crucifixion, insurer, aleksandar, opec,
# Nearest to three: six, four, five, seven, eight, two, nine, zero,
# Nearest to were: are, was, had, have, been, be, is, by,
# Nearest to two: three, four, six, one, five, eight, seven, nine,
# Nearest to used: known, factorials, play, found, provider, called, aristide, manchurian,
# Nearest to four: six, three, five, eight, seven, two, nine, one,
# Nearest to also: now, often, which, then, it, kohanim, still, commonly,
# Nearest to are: were, is, have, was, bingen, solvable, but, be,
# Nearest to would: can, will, could, may, must, might, should, to,
# Average loss at step 22000: 3.503723
# Average loss at step 24000: 3.489504
# Average loss at step 26000: 3.480847
# Average loss at step 28000: 3.478203
# Average loss at step 30000: 3.502204
# Nearest to however: but, although, when, where, belated, vr, qh, thoroughbred,
# Nearest to b: d, gimmick, monotheist, albarn, beverly, csv, bondage, vane,
# Nearest to the: their, its, anteater, many, conquer, these, backtracking, a,
# Nearest to zero: five, eight, seven, four, six, nine, three, two,
# Nearest to there: they, it, he, still, often, not, which, this,
# Nearest to no: steppenwolf, a, canine, lindy, amid, dave, there, wielding,
# Nearest to which: this, that, also, who, these, it, actually, there,
# Nearest to united: halifax, army, lottery, mullis, aleksandar, insurer, crashes, kingdoms,
# Nearest to three: five, four, seven, two, eight, six, nine, zero,
# Nearest to were: are, was, had, been, have, grosso, be, is,
# Nearest to two: three, four, five, one, seven, six, eight, nine,
# Nearest to used: known, found, called, seen, factorials, xavier, held, regarded,
# Nearest to four: five, eight, six, three, seven, nine, two, zero,
# Nearest to also: often, now, still, which, it, then, who, kohanim,
# Nearest to are: were, have, is, these, be, artistically, but, skeleton,
# Nearest to would: will, could, can, may, must, might, should, to,
# Average loss at step 32000: 3.502835
# Average loss at step 34000: 3.490988
# Average loss at step 36000: 3.461208
# Average loss at step 38000: 3.301383
# Average loss at step 40000: 3.433986
# Nearest to however: but, although, that, though, austrians, vr, since, where,
# Nearest to b: d, gimmick, f, gare, n, r, c, igg,
# Nearest to the: its, this, their, a, another, each, his, any,
# Nearest to zero: five, seven, eight, nine, six, four, three, two,
# Nearest to there: it, they, he, which, still, often, no, usually,
# Nearest to no: there, canine, any, wielding, a, amid, steppenwolf, lindy,
# Nearest to which: that, this, who, also, there, always, these, usually,
# Nearest to united: mullis, lottery, halifax, aleksandar, kingdoms, army, cowes, opec,
# Nearest to three: four, seven, two, six, five, eight, nine, one,
# Nearest to were: are, have, was, had, been, yad, be, when,
# Nearest to two: four, three, six, five, seven, eight, one, nine,
# Nearest to used: known, found, held, seen, written, available, called, defined,
# Nearest to four: six, three, eight, seven, two, five, nine, one,
# Nearest to also: now, often, still, which, commonly, typically, who, usually,
# Nearest to are: were, have, is, these, be, euphoria, artistically, while,
# Nearest to would: will, could, can, must, may, might, should, did,
# Average loss at step 42000: 3.431847
# Average loss at step 44000: 3.452504
# Average loss at step 46000: 3.449289
# Average loss at step 48000: 3.352268
# Average loss at step 50000: 3.386387
# Nearest to however: but, although, that, though, while, when, since, where,
# Nearest to b: d, f, c, n, gimmick, fillmore, gare, r,
# Nearest to the: its, their, his, backtracking, this, some, a, an,
# Nearest to zero: seven, five, eight, nine, four, six, two, three,
# Nearest to there: they, it, he, still, amputee, we, ochre, believed,
# Nearest to no: any, nothing, steppenwolf, a, wielding, amid, there, canine,
# Nearest to which: that, this, often, who, also, these, always, actually,
# Nearest to united: mullis, lottery, halifax, aleksandar, kingdoms, qualia, leste, opec,
# Nearest to three: four, seven, eight, six, five, nine, two, zero,
# Nearest to were: are, have, was, had, be, is, those, been,
# Nearest to two: three, four, seven, six, five, eight, zero, nine,
# Nearest to used: known, seen, written, found, available, possible, described, held,
# Nearest to four: seven, eight, six, five, three, nine, two, zero,
# Nearest to also: now, often, still, which, actually, then, commonly, typically,
# Nearest to are: were, is, have, these, although, those, be, artistically,
# Nearest to would: will, could, can, may, must, should, might, did,
# Average loss at step 52000: 3.433907
# Average loss at step 54000: 3.425494
# Average loss at step 56000: 3.435205
# Average loss at step 58000: 3.393480
# Average loss at step 60000: 3.396456
# Nearest to however: but, although, since, though, that, which, when, until,
# Nearest to b: d, f, c, h, n, fillmore, r, bootlegged,
# Nearest to the: their, its, a, this, his, our, each, some,
# Nearest to zero: five, four, eight, six, seven, nine, three, two,
# Nearest to there: it, they, this, he, still, often, we, now,
# Nearest to no: any, flatulence, bloodline, amid, reflexes, nothing, extremophiles, a,
# Nearest to which: that, this, what, however, also, it, who, there,
# Nearest to united: lottery, mullis, supreme, gino, opec, halifax, aleksandar, leste,
# Nearest to three: five, four, six, eight, two, nine, seven, one,
# Nearest to were: are, was, have, had, be, those, been, although,
# Nearest to two: four, three, five, six, one, eight, seven, nine,
# Nearest to used: known, seen, written, found, held, available, considered, described,
# Nearest to four: five, six, eight, seven, three, nine, two, zero,
# Nearest to also: now, still, often, actually, typically, which, commonly, it,
# Nearest to are: were, is, have, these, those, antiquated, be, including,
# Nearest to would: will, could, may, can, must, might, should, did,
# Average loss at step 62000: 3.242838
# Average loss at step 64000: 3.254496
# Average loss at step 66000: 3.403308
# Average loss at step 68000: 3.394578
# Average loss at step 70000: 3.359185
# Nearest to however: but, although, though, when, that, while, where, since,
# Nearest to b: d, h, f, r, n, z, j, fillmore,
# Nearest to the: their, its, any, this, a, each, these, another,
# Nearest to zero: five, six, four, eight, seven, nine, three, two,
# Nearest to there: they, it, we, he, still, this, now, she,
# Nearest to no: any, there, flatulence, substantial, heats, bloodline, nothing, regulator,
# Nearest to which: that, this, also, and, what, usually, often, but,
# Nearest to united: supreme, lottery, mullis, gino, cowes, caribbean, leste, goalkeepers,
# Nearest to three: four, six, five, two, seven, eight, nine, zero,
# Nearest to were: are, have, was, had, be, been, although, recognises,
# Nearest to two: three, six, four, one, five, seven, eight, zero,
# Nearest to used: known, available, written, seen, found, considered, described, referred,
# Nearest to four: five, three, six, eight, seven, zero, two, nine,
# Nearest to also: now, still, actually, often, which, below, generally, commonly,
# Nearest to are: were, have, is, although, while, including, include, these,
# Nearest to would: will, could, can, may, might, must, should, did,
# Average loss at step 72000: 3.374443
# Average loss at step 74000: 3.347131
# Average loss at step 76000: 3.321360
# Average loss at step 78000: 3.354432
# Average loss at step 80000: 3.375955
# Nearest to however: but, although, that, though, while, when, especially, cases,
# Nearest to b: d, f, c, r, h, z, fillmore, unknowingly,
# Nearest to the: their, its, a, his, this, dtds, walford, nongovernmental,
# Nearest to zero: seven, five, six, eight, four, three, nine, two,
# Nearest to there: it, they, he, still, we, often, she, usually,
# Nearest to no: little, any, flatulence, nothing, fancher, there, regulator, amid,
# Nearest to which: that, this, usually, often, what, who, also, located,
# Nearest to united: supreme, lottery, mullis, gino, leste, mourn, cowes, caribbean,
# Nearest to three: six, four, five, two, seven, eight, nine, zero,
# Nearest to were: are, have, was, had, be, being, recognises, been,
# Nearest to two: three, four, six, five, seven, eight, one, zero,
# Nearest to used: known, seen, written, available, found, referred, described, considered,
# Nearest to four: six, five, seven, eight, three, nine, two, zero,
# Nearest to also: now, still, actually, often, thus, never, commonly, which,
# Nearest to are: were, have, is, although, include, these, those, while,
# Nearest to would: will, could, can, may, might, must, should, did,
# Average loss at step 82000: 3.406968
# Average loss at step 84000: 3.408757
# Average loss at step 86000: 3.387726
# Average loss at step 88000: 3.355477
# Average loss at step 90000: 3.365933
# Nearest to however: but, although, though, that, since, while, where, especially,
# Nearest to b: d, f, r, z, h, n, fillmore, fossilized,
# Nearest to the: its, their, this, a, each, his, sinkholes, our,
# Nearest to zero: five, seven, eight, six, nine, four, three, two,
# Nearest to there: they, it, he, we, she, still, now, usually,
# Nearest to no: any, little, nothing, there, amid, insecurity, sampling, regulator,
# Nearest to which: that, this, what, who, usually, also, actually, always,
# Nearest to united: supreme, lottery, mullis, gino, opec, mourn, constitution, reunion,
# Nearest to three: two, four, five, eight, seven, six, nine, zero,
# Nearest to were: are, had, was, have, while, although, being, entanglement,
# Nearest to two: three, five, four, eight, six, seven, one, zero,
# Nearest to used: known, seen, referred, applied, described, found, considered, necessary,
# Nearest to four: seven, five, six, three, eight, nine, two, zero,
# Nearest to also: now, actually, still, often, which, never, generally, thus,
# Nearest to are: were, is, include, have, these, although, contain, while,
# Nearest to would: will, could, might, can, may, should, must, did,
# Average loss at step 92000: 3.400632
# Average loss at step 94000: 3.251682
# Average loss at step 96000: 3.354013
# Average loss at step 98000: 3.244830
# Average loss at step 100000: 3.356074
# Nearest to however: but, although, that, especially, though, and, where, since,
# Nearest to b: d, fillmore, introductions, csv, nanny, initiate, seu, undead,
# Nearest to the: their, his, our, a, its, your, her, headland,
# Nearest to zero: five, four, eight, six, seven, nine, three, two,
# Nearest to there: they, he, it, we, she, now, still, often,
# Nearest to no: any, little, regulator, there, another, steeped, drinks, amid,
# Nearest to which: that, this, actually, what, usually, who, slowdown, also,
# Nearest to united: supreme, lottery, mullis, gino, constitution, caribbean, mourn, senate,
# Nearest to three: five, four, six, two, eight, seven, nine, zero,
# Nearest to were: are, was, have, had, these, although, being, tentatively,
# Nearest to two: four, three, five, eight, seven, six, one, zero,
# Nearest to used: known, seen, referred, designed, written, applied, considered, described,
# Nearest to four: six, five, seven, eight, three, two, nine, zero,
# Nearest to also: actually, now, never, still, below, generally, often, usually,
# Nearest to are: were, those, contain, is, be, include, these, have,
# Nearest to would: will, could, might, may, can, must, should, did,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  cbow_batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    
    
    #cbow_batch[i*num_skips : (i+1)*num_skips+1]=(1/num_skips)*av
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    labels, batch = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [[bi] for bi in batch.reshape(8)])
    print('    labels:', [[li] for li in labels])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: [[5238], [12], [3082], [6], [195], [12], [6], [2]]
#     labels: [[3082], [3082], [12], [12], [6], [6], [195], [195]]
#
# with num_skips = 4 and skip_window = 2:
#     batch: [[3082], [5238], [195], [6], [195], [3082], [12], [2]]
#     labels: [[12], [12], [12], [12], [6], [6], [6], [6]]

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  embedSum = tf.Variable(
    tf.random_uniform([batch_size,embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  #print(embed.get_shape())
  #embedSum=np.ndarray(shape=(batch_size,embedding_size))
  # Compute the softmax loss, using a sample of the negative labels each time.
  
  for i in range(batch_size // num_skips):
      av=tf.zeros([1,embedding_size])
      #av=av.reshape(embedding_size,1)
      #print(av.get_shape())
      #a=tf.constant([[2,2,3],[2,2,3]])
      #print(a.get_shape())
      for j in range(num_skips):
        temp=tf.gather(embed,[i*num_skips+j])
        #print(temp.get_shape())
        av=tf.add(av,temp)
        #print(av.get_shape())
        embedSum=tf.scatter_update(embedSum,[i*num_skips +j],av)
        #embedSum[i*num_skips +j ,:]=(1/num_skips)*av     
    
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed,
                               train_labels, num_sampled, vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))
# Out:
# (128, 128)

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_labels, batch_data = generate_batch(
      batch_size, num_skips, skip_window)
    #print(batch_labels.shape)
    #print(batch_data.shape)
    batch_labels=batch_labels.reshape(batch_labels.shape[0],1)
    batch_data=batch_data.reshape(batch_data.shape[0])
    #print(batch_labels.shape)
    #print(batch_data.shape)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.104874
# Nearest to some: jessica, vet, gripping, reciprocated, chalk, dolphins, give, trisomy,
# Nearest to these: nter, carriages, launcher, mandy, pairs, uncomplicated, interviews, surrogate,
# Nearest to war: holiest, biography, marshals, switched, positions, judaica, cleverly, linebarger,
# Nearest to been: ghb, courtesy, crumble, ipf, corrections, kornilov, sling, monies,
# Nearest to will: velocity, chlorine, interim, pediatric, dealerships, boundless, concerns, acknowledges,
# Nearest to many: cow, harsh, connectors, slaps, paralipomena, valuable, fsf, abelard,
# Nearest to over: drusilla, issa, convex, luanda, temples, spaceman, solnhofen, abrasive,
# Nearest to also: kops, banach, technology, gurevich, tackle, jerome, essentials, plantae,
# Nearest to after: sequential, retired, apoplexy, nikola, batter, realized, protects, wallets,
# Nearest to during: bulldog, xxxviii, typed, cretaceous, southerner, sandwiches, slays, accepts,
# Nearest to see: verizon, cemeteries, acquisitions, sauropods, ravaged, torgau, ombudsman, lambeau,
# Nearest to however: putty, fib, salem, galeon, essays, taekwondo, musk, mexica,
# Nearest to were: growths, starter, hoe, zones, pullback, palatal, bambara, loaders,
# Nearest to five: magnolia, barth, countermeasure, gardeners, helga, luck, hornsby, bangui,
# Nearest to seven: misgivings, undemocratic, oicw, ulema, adapts, resolutely, someday, namek,
# Nearest to not: eurostar, vives, apocalypse, guthrie, princip, slogan, writer, strings,
# Average loss at step 2000: 4.327947
# Average loss at step 4000: 3.899608
# Average loss at step 6000: 3.726041
# Average loss at step 8000: 3.715991
# Average loss at step 10000: 3.616982
# Nearest to some: these, wisconsin, other, skyview, microwave, vehemently, paradise, several,
# Nearest to these: some, carriages, eritrean, pairs, trumps, charpentier, channels, shared,
# Nearest to war: crops, biography, crankshafts, switched, therese, positions, sqq, copies,
# Nearest to been: sling, was, by, kornilov, be, shatter, crumble, cashmere,
# Nearest to will: would, xt, contour, chlorine, may, ratites, velocity, should,
# Nearest to many: their, abelard, perineum, analytical, slaps, restraints, several, connectors,
# Nearest to over: solnhofen, luanda, mosfet, pia, monsanto, electrochemistry, plotted, enclosing,
# Nearest to also: sometimes, not, still, escrow, hydrofoil, that, it, nihilistic,
# Nearest to after: sequential, pok, before, enjoyable, bedrock, wallets, with, tera,
# Nearest to during: typed, modesty, exerts, sandwiches, in, advancements, trustworthy, behave,
# Nearest to see: kuro, verizon, sauropods, may, multiparty, civitas, corollary, passengers,
# Nearest to however: prospects, galeon, emergencies, salem, fits, platonism, yourself, moldovans,
# Nearest to were: are, was, growths, is, trevelyan, shire, strau, rescuing,
# Nearest to five: six, three, nine, seven, eight, four, two, zero,
# Nearest to seven: eight, four, three, nine, six, five, one, zero,
# Nearest to not: they, still, also, leena, there, it, crockett, catus,
# Average loss at step 12000: 3.557174
# Average loss at step 14000: 3.456199
# Average loss at step 16000: 3.490862
# Average loss at step 18000: 3.557183
# Average loss at step 20000: 3.522362
# Nearest to some: many, several, these, their, the, most, any, its,
# Nearest to these: some, many, which, several, both, channels, carriages, eritrean,
# Nearest to war: crops, switched, crankshafts, marshals, positions, therese, biography, sqq,
# Nearest to been: sling, be, was, by, become, kornilov, midfielder, vesque,
# Nearest to will: would, may, can, should, could, contour, must, cannot,
# Nearest to many: some, several, these, their, commentator, various, analytical, exorcism,
# Nearest to over: plotted, convex, mosfet, decryption, guile, pia, squalor, scientists,
# Nearest to also: which, still, sometimes, often, hydrofoil, escrow, that, not,
# Nearest to after: before, when, bedrock, at, pok, norfolk, enjoyable, telugu,
# Nearest to during: in, typed, modesty, advancements, entire, exerts, at, bal,
# Nearest to see: kuro, verizon, multiparty, sauropods, amplitudes, corollary, numidia, may,
# Nearest to however: but, emergencies, moldovans, prospects, generally, later, platonism, yoshitaka,
# Nearest to were: are, was, have, had, is, shire, growths, be,
# Nearest to five: four, six, eight, seven, zero, nine, three, two,
# Nearest to seven: six, eight, four, nine, five, three, one, zero,
# Nearest to not: still, leena, it, bgcolor, also, they, stf, mehmet,
# Average loss at step 22000: 3.502224
# Average loss at step 24000: 3.499233
# Average loss at step 26000: 3.468140
# Average loss at step 28000: 3.533111
# Average loss at step 30000: 3.494354
# Nearest to some: many, several, these, all, certain, their, most, microwave,
# Nearest to these: some, many, both, several, carriages, all, which, they,
# Nearest to war: crops, crankshafts, therese, switched, copies, marshals, positions, dns,
# Nearest to been: was, be, sling, were, become, had, supposedly, already,
# Nearest to will: would, can, may, could, should, must, cannot, to,
# Nearest to many: some, several, these, various, those, exorcism, all, such,
# Nearest to over: answer, mosfet, decryption, shell, convex, guile, precept, since,
# Nearest to also: which, often, sometimes, now, still, escrow, deane, nihilistic,
# Nearest to after: before, when, for, fini, pok, from, pcc, into,
# Nearest to during: in, at, when, through, typed, on, modesty, entire,
# Nearest to see: verizon, zhdanov, multiparty, civitas, kuro, obscurity, amplitudes, corollary,
# Nearest to however: but, emergencies, moldovans, realistically, where, abauzit, multiplication, requires,
# Nearest to were: are, had, was, have, been, be, shire, being,
# Nearest to five: four, six, seven, three, eight, zero, nine, two,
# Nearest to seven: four, six, five, eight, nine, three, zero, one,
# Nearest to not: still, they, usually, never, prepared, it, tanoana, also,
# Average loss at step 32000: 3.504313
# Average loss at step 34000: 3.449393
# Average loss at step 36000: 3.335096
# Average loss at step 38000: 3.436341
# Average loss at step 40000: 3.447019
# Nearest to some: many, these, several, their, certain, those, both, this,
# Nearest to these: many, some, both, such, all, several, various, those,
# Nearest to war: crankshafts, crops, therese, switched, rhombicuboctahedron, copies, marshals, sqq,
# Nearest to been: become, be, was, sling, were, had, already, supposedly,
# Nearest to will: would, can, may, could, should, must, cannot, might,
# Nearest to many: some, several, these, various, other, those, such, their,
# Nearest to over: answer, spoleto, guile, scientists, precept, squalor, decryption, circa,
# Nearest to also: often, which, sometimes, now, still, there, commonly, traditionally,
# Nearest to after: before, when, during, upon, fini, through, invocations, without,
# Nearest to during: in, when, at, through, before, after, on, typed,
# Nearest to see: verizon, zhdanov, insolvency, numidia, can, kuro, obscurity, amplitudes,
# Nearest to however: but, that, moldovans, though, although, emergencies, which, abauzit,
# Nearest to were: are, have, had, was, although, been, maturation, be,
# Nearest to five: six, four, seven, eight, three, two, zero, nine,
# Nearest to seven: eight, six, four, nine, five, three, zero, two,
# Nearest to not: usually, they, still, it, prepared, never, bangladeshis, also,
# Average loss at step 42000: 3.451961
# Average loss at step 44000: 3.457202
# Average loss at step 46000: 3.347724
# Average loss at step 48000: 3.403372
# Average loss at step 50000: 3.438380
# Nearest to some: many, several, these, their, certain, both, any, various,
# Nearest to these: some, many, both, such, several, those, various, all,
# Nearest to war: crops, therese, rhombicuboctahedron, crankshafts, switched, gare, marshals, brun,
# Nearest to been: be, become, sling, were, supposedly, had, gone, was,
# Nearest to will: would, can, could, may, must, should, might, cannot,
# Nearest to many: some, several, these, various, those, both, such, most,
# Nearest to over: through, distinctly, off, spoleto, into, decryption, answer, guile,
# Nearest to also: often, now, which, sometimes, still, nihilistic, never, largely,
# Nearest to after: before, when, during, upon, fini, while, without, from,
# Nearest to during: in, after, when, before, through, at, of, from,
# Nearest to see: zhdanov, include, verizon, sluggish, insolvency, numidia, kuro, list,
# Nearest to however: but, although, though, while, that, where, moldovans, which,
# Nearest to were: are, was, have, had, been, bsi, valery, be,
# Nearest to five: four, six, eight, zero, seven, three, nine, two,
# Nearest to seven: eight, six, five, four, nine, three, zero, one,
# Nearest to not: usually, still, they, now, nsson, generally, bangladeshis, never,
# Average loss at step 52000: 3.433078
# Average loss at step 54000: 3.430817
# Average loss at step 56000: 3.406435
# Average loss at step 58000: 3.394430
# Average loss at step 60000: 3.212001
# Nearest to some: many, several, these, most, certain, those, both, impassioned,
# Nearest to these: some, many, several, such, all, those, both, which,
# Nearest to war: therese, rhombicuboctahedron, crankshafts, viola, marriages, crops, bestial, dns,
# Nearest to been: become, be, sling, supposedly, was, had, were, successfully,
# Nearest to will: would, could, can, must, may, should, cannot, might,
# Nearest to many: some, several, various, these, those, all, such, most,
# Nearest to over: decryption, bottlenose, through, answer, spoleto, circa, tapped, guile,
# Nearest to also: now, often, still, sometimes, escrow, which, underestimate, monoxide,
# Nearest to after: before, during, when, upon, without, for, while, fini,
# Nearest to during: after, in, before, when, following, while, however, including,
# Nearest to see: list, include, zhdanov, fries, can, sluggish, lumi, insolvency,
# Nearest to however: but, although, though, that, while, which, when, during,
# Nearest to were: are, was, have, had, be, valery, including, maturation,
# Nearest to five: four, three, six, eight, seven, nine, two, zero,
# Nearest to seven: eight, six, four, nine, three, five, two, one,
# Nearest to not: still, they, never, usually, now, bangladeshis, marginalism, only,
# Average loss at step 62000: 3.301077
# Average loss at step 64000: 3.409964
# Average loss at step 66000: 3.392092
# Average loss at step 68000: 3.349136
# Average loss at step 70000: 3.381849
# Nearest to some: many, these, several, both, certain, this, all, various,
# Nearest to these: some, many, such, those, several, all, their, both,
# Nearest to war: therese, rhombicuboctahedron, marriages, viola, attackers, gare, brun, crops,
# Nearest to been: become, be, sling, supposedly, gone, was, successfully, were,
# Nearest to will: would, could, must, can, may, should, cannot, might,
# Nearest to many: some, several, various, these, all, those, both, such,
# Nearest to over: answer, through, about, gaunt, decryption, gholas, precept, guile,
# Nearest to also: now, still, often, sometimes, never, which, specter, not,
# Nearest to after: before, during, when, upon, without, despite, until, while,
# Nearest to during: after, before, in, through, when, following, until, at,
# Nearest to see: include, zhdanov, fries, list, insolvency, although, but, including,
# Nearest to however: but, although, though, while, when, that, where, moldovans,
# Nearest to were: are, have, had, was, psychopathic, although, these, including,
# Nearest to five: six, four, eight, three, seven, nine, two, one,
# Nearest to seven: eight, six, five, nine, four, three, one, two,
# Nearest to not: still, now, also, usually, bangladeshis, never, always, probably,
# Average loss at step 72000: 3.359562
# Average loss at step 74000: 3.326643
# Average loss at step 76000: 3.366092
# Average loss at step 78000: 3.376110
# Average loss at step 80000: 3.409418
# Nearest to some: many, several, certain, various, these, both, this, all,
# Nearest to these: several, many, such, those, some, various, both, they,
# Nearest to war: therese, viola, wars, bord, brun, crankshafts, attackers, abruptly,
# Nearest to been: become, be, sling, was, recently, supposedly, gone, had,
# Nearest to will: would, could, can, may, must, should, cannot, might,
# Nearest to many: some, several, various, these, numerous, those, both, all,
# Nearest to over: about, gaunt, bottlenose, off, around, across, decryption, modeled,
# Nearest to also: still, now, often, sometimes, never, which, specter, not,
# Nearest to after: before, during, when, without, upon, despite, until, while,
# Nearest to during: after, in, before, following, through, when, although, at,
# Nearest to see: includes, kuro, include, fries, references, vetoes, verizon, zhdanov,
# Nearest to however: but, although, though, that, especially, while, which, when,
# Nearest to were: are, had, was, have, although, include, psychopathic, being,
# Nearest to five: four, six, eight, seven, three, nine, zero, two,
# Nearest to seven: eight, four, six, nine, five, three, one, two,
# Nearest to not: still, usually, often, now, never, also, always, actually,
# Average loss at step 82000: 3.409166
# Average loss at step 84000: 3.380798
# Average loss at step 86000: 3.363409
# Average loss at step 88000: 3.379417
# Average loss at step 90000: 3.387579
# Nearest to some: many, certain, several, these, this, any, both, those,
# Nearest to these: several, many, some, those, such, both, various, certain,
# Nearest to war: therese, brun, bord, viola, crankshafts, wars, friar, attackers,
# Nearest to been: become, be, was, already, sling, recently, supposedly, previously,
# Nearest to will: would, could, can, must, may, should, cannot, might,
# Nearest to many: several, some, various, these, all, numerous, certain, those,
# Nearest to over: answer, off, about, gaunt, around, precept, bottlenose, alnus,
# Nearest to also: now, still, often, sometimes, never, which, commonly, usually,
# Nearest to after: before, during, when, without, despite, while, upon, until,
# Nearest to during: after, in, before, through, when, at, alleys, within,
# Nearest to see: list, include, includes, kuro, references, vigil, fries, lumi,
# Nearest to however: but, although, though, that, while, especially, and, cases,
# Nearest to were: are, had, was, while, have, although, psychopathic, those,
# Nearest to five: four, seven, six, three, eight, two, one, nine,
# Nearest to seven: five, eight, six, four, nine, three, zero, one,
# Nearest to not: still, actually, never, bangladeshis, also, usually, t, now,
# Average loss at step 92000: 3.270764
# Average loss at step 94000: 3.342994
# Average loss at step 96000: 3.242270
# Average loss at step 98000: 3.369681
# Average loss at step 100000: 3.327820
# Nearest to some: many, several, certain, these, any, all, numerous, those,
# Nearest to these: several, many, all, some, those, instead, various, such,
# Nearest to war: therese, attackers, brun, crankshafts, friar, wars, viola, marriages,
# Nearest to been: become, be, already, was, supposedly, sling, recently, were,
# Nearest to will: would, could, can, must, should, may, cannot, might,
# Nearest to many: some, several, various, all, these, those, numerous, certain,
# Nearest to over: answer, around, about, gaunt, off, precept, alnus, spanned,
# Nearest to also: now, never, sometimes, still, often, which, traditionally, actually,
# Nearest to after: before, when, during, without, while, despite, from, upon,
# Nearest to during: after, in, at, before, through, throughout, within, despite,
# Nearest to see: references, include, kuro, includes, refer, list, vigil, lumi,
# Nearest to however: but, although, though, especially, while, that, which, where,
# Nearest to were: are, was, had, have, although, being, these, been,
# Nearest to five: four, seven, eight, six, three, nine, zero, two,
# Nearest to seven: eight, six, four, nine, five, three, zero, two,
# Nearest to not: still, t, never, bangladeshis, almost, always, bgcolor, now,
